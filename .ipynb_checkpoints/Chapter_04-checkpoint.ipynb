# %% [markdown]
# # แบบฝึกหัดบทที่ 4 พื้นฐานโปรแกรมไพธอน

# %%
""" 
นาย ภูพิรัฐ แซ่โค้ว : 6812732119
"""

# %% [markdown]
# ## 1. จงอธิบายความหมายของคำว่า Syntax

# %% [markdown]
# # คำตอบ
# หลักไวยากรณ์ คือ ข้อกำหนดในการเขียนโปรแกรมที่ตัวแปรภาษาสามารถประมวลผล และเข้าใจได้

# %% [markdown]
# ## 2.จงอธิบายความหมายของคำว่า Semantics

# %%
# คำตอบ
หมายถึง
“ความหมายของคำสั่งหรือโค้ด” — คือสิ่งที่บอกว่าโค้ดนั้น ทำงานอย่างไร หรือ เกิดผลอะไรขึ้นเมื่อรันคำสั่งนั้น

# %% [markdown]
# ## 3.Identifiers คืออะไร

# %%
#คำตอบ
ชื่อที่ผู้เขียนโปรแกรมกำหนดขึ้นเพื่ออ้างอิงสิ่งต่าง ๆ ภายในโปรแกรม
เช่น ตัวแปร (variable), ฟังก์ชัน (function), คลาส (class), โมดูล (module) หรือ อ็อบเจ็กต์อื่น ๆ
# Out:
#   Cell In[11], line 1
#     ชื่อที่ผู้เขียนโปรแกรมกำหนดขึ้นเพื่ออ้างอิงสิ่งต่าง ๆ ภายในโปรแกรม
#                                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 4.คำสงวนในภาษาไพธอนคืออะไร และมีทั้งหมดกี่คำ

# %%
#คำตอบ
คือคำที่ถูกระบบภาษา Python จองไว้ใช้งานเฉพาะ สำหรับเป็นส่วนหนึ่งของไวยากรณ์ภาษา เช่น การประกาศตัวแปร การสร้างเงื่อนไข หรือการวนซ้ำ มีทั้งหมด 35 คำ

# %% [markdown]
# ## 5.จงเขียนโปรแกรมไพธอนเพื่อรับข้อมูล ที่เป็นชื่อผู้ใช้งานจากแป้นพิมพ์และแสดงออกทางหน้าจอ

# %%
# พิมพ์โค้ดโปรแกรมด้านล่างนี้
a = input("Your name")
print(a)
# Out:
# Your name Tar
# Tar

# %% [markdown]
# ## 6.จงเขียนโปรแกรมเพื่อแสดงค่าของ pi คือ 3.14159 ออกทางหน้าจอโดยทำการกำหนดรูปแบบในการแสดงผลดังต่อไปนี้
#
# - pi = 3
# - pi = 3.14
# - pi = 3.1416

# %%
# พิมพ์โค้ดโปรแกรมด้านล่างนี้
print ("pi = 3")
print ("pi = 3.14")
print ("pi = 3.1415")
# Out:
# pi = 3
# pi = 3.14
# pi = 3.1415

# %% [markdown]
# ## 7.	จงเขียนโปรแกรมที่แสดงคำว่า "dog", "cat", "bat" ออกทางหน้าจอ โดยกำหนดรูปแบบในการแสดงดังต่อไปนี้

# %%
""" 
|dog       |   cat    |       bat| 
"""

# %%
# พิมพ์โค้ดโปรแกรมด้านล่างนี้
print ("|dog       |   cat    |       bat|")
# Out:
# |dog       |   cat    |       bat|

# %% [markdown]
# ## 8.	จงเขียนโปรแกรมที่แสดงคำว่า "dog", "cat", "bat" ออกทางหน้าจอ โดยกำหนดรูปแบบในการแสดงดังต่อไปนี้

# %%
""" 
|dog*******|***cat****|*******bat| 
"""

# %%
# พิมพ์โค้ดโปรแกรมด้านล่างนี้
print ("|dog*******|***cat****|*******bat|")
# Out:
# |dog*******|***cat****|*******bat|
